# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets

# %%
df = pd.read_csv("./assets/data_100000.csv")

# %%
df.head()
# Out:
#    created_at  tree_id  block_id  \
# 0  08/27/2015   180683    348711
# 1  09/03/2015   200540    315986
# 2  09/05/2015   204026    218365
# 3  09/05/2015   204337    217969
# 4  08/30/2015   189565    223043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health                           spc_latin  ... st_assem  \
# 0   OnCurb  Alive   Fair                         Acer rubrum  ...       28
# 1   OnCurb  Alive   Fair                   Quercus palustris  ...       27
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...       50
# ...

# %% [markdown]
# ## drop useless columns

# %%
df.columns
# Out:
# Index(['created_at', 'tree_id', 'block_id', 'the_geom', 'tree_dbh',
#        'stump_diam', 'curb_loc', 'status', 'health', 'spc_latin', 'spc_common',
#        'steward', 'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trnk_wire', 'trnk_light', 'trnk_other',
#        'brnch_ligh', 'brnch_shoe', 'brnch_othe', 'address', 'zipcode',
#        'zip_city', 'cb_num', 'borocode', 'boroname', 'cncldist', 'st_assem',
#        'st_senate', 'nta', 'nta_name', 'boro_ct', 'state', 'latitude',
#        'longitude', 'x_sp', 'y_sp'],
#       dtype='object')

# %%
df.address
# Out:
# 0           108-005 70 AVENUE
# 1            147-074 7 AVENUE
# 2           390 MORGAN AVENUE
# 3           1027 GRAND STREET
# 4                603 6 STREET
#                  ...
# 99995    201 ASPINWALL STREET
# 99996    201 ASPINWALL STREET
# 99997       237-010 32 AVENUE
# 99998          4 MIDLAND ROAD
# 99999    450 NORTH END AVENUE
# Name: address, Length: 100000, dtype: object

# %%
# df['address'].value_counts()

# %%
df = df.drop(['state','problems','guards','steward','x_sp','y_sp','boroname','zip_city','spc_latin'],axis=1)# delete unnecessary columns 'state'...

# %%
df.head()
# Out:
#    created_at  tree_id  block_id  \
# 0  08/27/2015   180683    348711
# 1  09/03/2015   200540    315986
# 2  09/05/2015   204026    218365
# 3  09/05/2015   204337    217969
# 4  08/30/2015   189565    223043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health       spc_common  ... cb_num borocode cncldist  \
# 0   OnCurb  Alive   Fair        red maple  ...    406        4       29
# 1   OnCurb  Alive   Fair          pin oak  ...    407        4       19
# 2   OnCurb  Alive   Good      honeylocust  ...    301        3       34
# ...

# %%
type(df['created_at'])
df['created_at'].dtypes# 'created_at' column to datetime series
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 33 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   created_at  100000 non-null  object
#  1   tree_id     100000 non-null  int64
#  2   block_id    100000 non-null  int64
#  3   the_geom    100000 non-null  object
#  4   tree_dbh    100000 non-null  int64
#  5   stump_diam  100000 non-null  int64
#  6   curb_loc    100000 non-null  object
#  7   status      100000 non-null  object
#  8   health      95007 non-null   object
#  9   spc_common  95008 non-null   object
#  10  sidewalk    95008 non-null   object
#  11  user_type   100000 non-null  object
#  12  root_stone  100000 non-null  object
#  13  root_grate  100000 non-null  object
#  14  root_other  100000 non-null  object
#  15  trnk_wire   100000 non-null  object
#  16  trnk_light  100000 non-null  object
#  17  trnk_other  100000 non-null  object
# ...

# %% [markdown]
# ## find null values and deal with them

# %%
df.isnull().sum()
# Out:
# created_at       0
# tree_id          0
# block_id         0
# the_geom         0
# tree_dbh         0
# stump_diam       0
# curb_loc         0
# status           0
# health        4993
# spc_common    4992
# sidewalk      4992
# user_type        0
# root_stone       0
# root_grate       0
# root_other       0
# trnk_wire        0
# trnk_light       0
# trnk_other       0
# brnch_ligh       0
# brnch_shoe       0
# brnch_othe       0
# address          0
# zipcode          0
# cb_num           0
# borocode         0
# cncldist         0
# st_assem         0
# st_senate        0
# nta              0
# nta_name         0
# boro_ct          0
# latitude         0
# longitude        0
# dtype: int64

# %%
df.health.value_counts()
# Out:
# Good    72340
# Fair    17266
# Poor     5401
# Name: health, dtype: int64

# %%
df.describe(include='all').T
# Out:
#              count unique                                           top  \
# created_at  100000    146                                    09/23/2015
# tree_id     100000    NaN                                           NaN
# block_id    100000    NaN                                           NaN
# the_geom    100000  99962  POINT (-73.95680061508556 40.61596593024687)
# tree_dbh    100000    NaN                                           NaN
# stump_diam  100000    NaN                                           NaN
# curb_loc    100000      2                                        OnCurb
# status      100000      3                                         Alive
# health       95007      3                                          Good
# spc_common   95008    125                              London planetree
# sidewalk     95008      2                                      NoDamage
# user_type   100000      3                                     Volunteer
# ...

# %%
df['health'].fillna(value='unknown',inplace=True)
df['spc_common'].fillna(value='unknown',inplace=True)
df['sidewalk'].fillna(value='unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# created_at    0
# tree_id       0
# block_id      0
# the_geom      0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# spc_common    0
# sidewalk      0
# user_type     0
# root_stone    0
# root_grate    0
# root_other    0
# trnk_wire     0
# trnk_light    0
# trnk_other    0
# brnch_ligh    0
# brnch_shoe    0
# brnch_othe    0
# address       0
# zipcode       0
# cb_num        0
# borocode      0
# cncldist      0
# st_assem      0
# st_senate     0
# nta           0
# nta_name      0
# boro_ct       0
# latitude      0
# longitude     0
# dtype: int64

# %% [markdown]
# ## create datetime column

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df['created_at']
# Out:
# 0       2015-08-27
# 1       2015-09-03
# 2       2015-09-05
# 3       2015-09-05
# 4       2015-08-30
#            ...
# 99995   2015-10-08
# 99996   2015-10-08
# 99997   2015-10-10
# 99998   2015-10-08
# 99999   2015-10-02
# Name: created_at, Length: 100000, dtype: datetime64[ns]

# %% [markdown]
# ## change categorical to numerical values

# %%
# dtype

# %%
# df.duplicated()

# %%
# df.apply(lambda x:)

# %%
# pd.get_dummies(df, prefix="")

# %%
# df.rename(columns={"from" : "to"})

# %% [markdown]
# # feature normalization and resampling?????
